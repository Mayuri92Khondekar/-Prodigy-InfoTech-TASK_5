# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_USA=pd.read_csv("D:\\US_Accidents_Dec21_Cleaned.csv\\US_Accidents_Dec21_Cleaned.csv")

# %%
df_USA.head()
# Out:
#    Unnamed: 0   ID  Severity           Start_Time             End_Time  \
# 0           0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08
# 1           4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43
# 2           5  A-6         2  2016-02-08 08:16:57  2016-02-08 14:16:57
# 3           6  A-7         2  2016-02-08 08:15:41  2016-02-08 14:15:41
# 4           7  A-8         2  2016-02-08 11:51:46  2016-02-08 17:51:46
#
#    Start_Lat  Start_Lng  Distance(mi)  \
# 0  40.108910 -83.092860         3.230
# 1  39.172393 -84.492792         0.500
# 2  39.063240 -84.032430         1.427
# 3  39.775650 -84.186030         0.227
# 4  41.375310 -81.820170         0.521
#
#                                          Description          Street  ...  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...     Outerbelt E  ...
# 1                 At Mitchell Ave/Exit 6 - Accident.          I-75 S  ...
# 2                       At Dela Palma Rd - Accident.  State Route 32  ...
# 3                        At OH-4/Exit 54 - Accident.          I-75 S  ...
# 4                  At Bagley Rd/Exit 235 - Accident.          I-71 S  ...
#
#   Amenity Crossing Junction Station   Stop Traffic_Signal Sunrise_Sunset  \
# 0   False    False    False   False  False          False          Night
# 1   False    False    False   False  False          False            Day
# 2   False    False    False   False  False           True            Day
# 3   False    False    False   False  False          False            Day
# 4   False    False     True   False  False          False            Day
#
#   Civil_Twilight Nautical_Twilight  Astronomical_Twilight
# 0          Night             Night                  Night
# 1            Day               Day                    Day
# 2            Day               Day                    Day
# 3            Day               Day                    Day
# 4            Day               Day                    Day
#
# [5 rows x 36 columns]

# %%
df_USA.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'Distance(mi)', 'Description', 'Street', 'Side', 'City',
#        'County', 'State', 'Zipcode', 'Country', 'Timezone', 'Airport_Code',
#        'Weather_Timestamp', 'Temperature(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Weather_Condition', 'Amenity', 'Crossing', 'Junction', 'Station',
#        'Stop', 'Traffic_Signal', 'Sunrise_Sunset', 'Civil_Twilight',
#        'Nautical_Twilight', 'Astronomical_Twilight'],
#       dtype='object')

# %%
df_USA.dtypes.value_counts()
# Out:
# object     20
# float64     8
# bool        6
# int64       2
# dtype: int64

# %% [markdown]
# # Shape of original data

# %%
df_USA.shape   # USA DATASET
# Out:
# (2655883, 36)

# %% [markdown]
# num_col=df.select_dtypes('number')
# cat_col=df.select_dtypes('object')
# bool_col=df.select_dtypes('bool')
# float_col=df.select_dtypes('float64')
# float_col=df.select_dtypes('int64')

# %% [markdown]
# missing_data = df.isna().sum(axis=0).sort_values(ascending=True)
# missing_data = missing_data.to_frame()
# missing_data.columns = ['missing_count']
# missing_data = missing_data.loc[missing_data['missing_count']>0]
#
# missing_data

# %%
# COLUMN NUMBER has highest no of null value , we cam drop that col further

# %%
df_USA.describe()
# Out:
#          Unnamed: 0      Severity     Start_Lat     Start_Lng  Distance(mi)  \
# count  2.655883e+06  2.655883e+06  2.655883e+06  2.655883e+06  2.655883e+06
# mean   1.415505e+06  2.125913e+00  3.618479e+01 -9.702782e+01  6.950144e-01
# std    8.056112e+05  4.621695e-01  5.395983e+00  1.828484e+01  1.533203e+00
# min    0.000000e+00  1.000000e+00  2.456603e+01 -1.245481e+02  0.000000e+00
# 25%    7.219635e+05  2.000000e+00  3.333905e+01 -1.180231e+02  5.000000e-02
# 50%    1.410348e+06  2.000000e+00  3.602264e+01 -9.199738e+01  2.370000e-01
# 75%    2.106166e+06  2.000000e+00  4.015119e+01 -8.038116e+01  7.610000e-01
# max    2.845341e+06  4.000000e+00  4.900058e+01 -6.711317e+01  1.551860e+02
#
#        Temperature(F)   Humidity(%)  Pressure(in)  Visibility(mi)  \
# count    2.655883e+06  2.655883e+06  2.655883e+06    2.655883e+06
# mean     6.196561e+01  6.415090e+01  2.945955e+01    9.107033e+00
# std      1.858038e+01  2.282721e+01  1.046353e+00    2.662482e+00
# min     -3.300000e+01  1.000000e+00  2.000000e-02    0.000000e+00
# 25%      5.000000e+01  4.800000e+01  2.930000e+01    1.000000e+01
# 50%      6.400000e+01  6.600000e+01  2.981000e+01    1.000000e+01
# 75%      7.600000e+01  8.300000e+01  3.000000e+01    1.000000e+01
# max      1.960000e+02  1.000000e+02  5.890000e+01    1.400000e+02
#
#        Wind_Speed(mph)
# count     2.655883e+06
# mean      7.398387e+00
# std       5.504851e+00
# min       0.000000e+00
# 25%       3.500000e+00
# 50%       7.000000e+00
# 75%       1.000000e+01
# max       1.087000e+03

# %%
df_USA.State.unique
# Out:
# <bound method Series.unique of 0          OH
# 1          OH
# 2          OH
# 3          OH
# 4          OH
#            ..
# 2655878    CA
# 2655879    CA
# 2655880    CA
# 2655881    CA
# 2655882    CA
# Name: State, Length: 2655883, dtype: object>

# %%
df1=df_USA[df_USA['State']=='CA']

# %%
df1['IDD'] = df1['ID'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
# Out:
# C:\Users\OWNER\AppData\Local\Temp\ipykernel_11772\1955134751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['IDD'] = df1['ID'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

# %%
df1
# Out:
#          Unnamed: 0         ID  Severity           Start_Time  \
# 880             990      A-991         3  2016-03-22 20:07:32
# 881             991      A-992         2  2016-03-22 21:40:18
# 882             992      A-993         2  2016-03-22 21:36:42
# 883             993      A-994         2  2016-03-22 21:36:42
# 884             994      A-995         2  2016-03-23 03:48:55
# ...             ...        ...       ...                  ...
# 2655878     2845337  A-2845338         2  2019-08-23 18:03:25
# 2655879     2845338  A-2845339         2  2019-08-23 19:11:30
# 2655880     2845339  A-2845340         2  2019-08-23 19:00:21
# 2655881     2845340  A-2845341         2  2019-08-23 19:00:21
# 2655882     2845341  A-2845342         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng  Distance(mi)  \
# 880      2016-03-23 02:07:32  37.881943 -122.307987         0.276
# 881      2016-03-23 03:40:18  37.881038 -122.307788         0.170
# 882      2016-03-23 03:36:42  38.518811 -121.101664         0.000
# 883      2016-03-23 03:36:42  38.518811 -121.101664         0.000
# 884      2016-03-23 09:48:55  36.990300 -119.711460         0.012
# ...                      ...        ...         ...           ...
# 2655878  2019-08-23 18:32:01  34.002480 -117.379360         0.543
# 2655879  2019-08-23 19:38:23  32.766960 -117.148060         0.338
# 2655880  2019-08-23 19:28:49  33.775450 -117.847790         0.561
# 2655881  2019-08-23 19:29:42  33.992460 -118.403020         0.772
# 2655882  2019-08-23 19:21:31  34.133930 -117.230920         0.537
#
#                                                Description            Street  \
# 880               At I-80/I-580 Northern Split - Accident.           I-580 W
# 881               At I-80/I-580 Northern Split - Accident.           I-580 W
# 882      Between Latrobe Rd/Indio Dr and Latrobe Rd - A...        Latrobe Rd
# 883      Between Latrobe Rd and Latrobe Rd/Indio Dr - A...        Latrobe Rd
# 884                 At North Fork Rd - Overturned vehicle.       N Friant Rd
# ...                                                    ...               ...
# 2655878                           At Market St - Accident.      Pomona Fwy E
# 2655879    At Camino Del Rio/Mission Center Rd - Accident.             I-8 W
# 2655880  At Glassell St/Grand Ave - Accident. in the ri...  Garden Grove Fwy
# 2655881     At CA-90/Marina Fwy/Jefferson Blvd - Accident.   San Diego Fwy S
# 2655882              At Highland Ave/Arden Ave - Accident.          CA-210 W
#
#          ... Crossing Junction Station   Stop Traffic_Signal Sunrise_Sunset  \
# 880      ...    False     True   False  False          False          Night
# 881      ...    False    False   False  False          False          Night
# 882      ...    False    False   False  False          False          Night
# 883      ...    False    False   False  False          False          Night
# 884      ...    False    False   False   True          False          Night
# ...      ...      ...      ...     ...    ...            ...            ...
# 2655878  ...    False    False   False  False          False            Day
# 2655879  ...    False    False   False  False          False            Day
# 2655880  ...    False     True   False  False          False            Day
# 2655881  ...    False    False   False  False          False            Day
# 2655882  ...    False    False   False  False          False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight      IDD
# 880              Night               Day                   Day      991
# 881              Night             Night                 Night      992
# 882              Night             Night                 Night      993
# 883              Night             Night                 Night      994
# 884              Night             Night                 Night      995
# ...                ...               ...                   ...      ...
# 2655878            Day               Day                   Day  2845338
# 2655879            Day               Day                   Day  2845339
# 2655880            Day               Day                   Day  2845340
# 2655881            Day               Day                   Day  2845341
# 2655882            Day               Day                   Day  2845342
#
# [741328 rows x 37 columns]

# %%
#df1['ID'].astype('int64')
#df1['ID'] = df1['ID'].astype(int)

# %%
df1.head()
# Out:
#      Unnamed: 0     ID  Severity           Start_Time             End_Time  \
# 880         990  A-991         3  2016-03-22 20:07:32  2016-03-23 02:07:32
# 881         991  A-992         2  2016-03-22 21:40:18  2016-03-23 03:40:18
# 882         992  A-993         2  2016-03-22 21:36:42  2016-03-23 03:36:42
# 883         993  A-994         2  2016-03-22 21:36:42  2016-03-23 03:36:42
# 884         994  A-995         2  2016-03-23 03:48:55  2016-03-23 09:48:55
#
#      Start_Lat   Start_Lng  Distance(mi)  \
# 880  37.881943 -122.307987         0.276
# 881  37.881038 -122.307788         0.170
# 882  38.518811 -121.101664         0.000
# 883  38.518811 -121.101664         0.000
# 884  36.990300 -119.711460         0.012
#
#                                            Description       Street  ...  \
# 880           At I-80/I-580 Northern Split - Accident.      I-580 W  ...
# 881           At I-80/I-580 Northern Split - Accident.      I-580 W  ...
# 882  Between Latrobe Rd/Indio Dr and Latrobe Rd - A...   Latrobe Rd  ...
# 883  Between Latrobe Rd and Latrobe Rd/Indio Dr - A...   Latrobe Rd  ...
# 884             At North Fork Rd - Overturned vehicle.  N Friant Rd  ...
#
#     Crossing Junction Station   Stop Traffic_Signal Sunrise_Sunset  \
# 880    False     True   False  False          False          Night
# 881    False    False   False  False          False          Night
# 882    False    False   False  False          False          Night
# 883    False    False   False  False          False          Night
# 884    False    False   False   True          False          Night
#
#     Civil_Twilight Nautical_Twilight Astronomical_Twilight  IDD
# 880          Night               Day                   Day  991
# 881          Night             Night                 Night  992
# 882          Night             Night                 Night  993
# 883          Night             Night                 Night  994
# 884          Night             Night                 Night  995
#
# [5 rows x 37 columns]

# %%
df1.shape
# Out:
# (741328, 37)

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'Distance(mi)', 'Description', 'Street', 'Side', 'City',
#        'County', 'State', 'Zipcode', 'Country', 'Timezone', 'Airport_Code',
#        'Weather_Timestamp', 'Temperature(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Weather_Condition', 'Amenity', 'Crossing', 'Junction', 'Station',
#        'Stop', 'Traffic_Signal', 'Sunrise_Sunset', 'Civil_Twilight',
#        'Nautical_Twilight', 'Astronomical_Twilight', 'IDD'],
#       dtype='object')

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.shape
# Out:
# (741328, 37)

# %%
df1=df1.dropna(subset=['Temperature(F)','Humidity(%)','Pressure(in)','Visibility(mi)','Wind_Direction', 'Wind_Speed(mph)',
                      'Weather_Condition'])

# %%
df1.shape
# Out:
# (741328, 37)

# %%
df1.isna().sum()/len(df1)*100
# Out:
# Unnamed: 0               0.0
# ID                       0.0
# Severity                 0.0
# Start_Time               0.0
# End_Time                 0.0
# Start_Lat                0.0
# Start_Lng                0.0
# Distance(mi)             0.0
# Description              0.0
# Street                   0.0
# Side                     0.0
# City                     0.0
# County                   0.0
# State                    0.0
# Zipcode                  0.0
# Country                  0.0
# Timezone                 0.0
# Airport_Code             0.0
# Weather_Timestamp        0.0
# Temperature(F)           0.0
# Humidity(%)              0.0
# Pressure(in)             0.0
# Visibility(mi)           0.0
# Wind_Direction           0.0
# Wind_Speed(mph)          0.0
# Weather_Condition        0.0
# Amenity                  0.0
# Crossing                 0.0
# Junction                 0.0
# Station                  0.0
# Stop                     0.0
# Traffic_Signal           0.0
# Sunrise_Sunset           0.0
# Civil_Twilight           0.0
# Nautical_Twilight        0.0
# Astronomical_Twilight    0.0
# IDD                      0.0
# dtype: float64

# %%
df1=df1.dropna(subset=['City','Sunrise_Sunset',
       'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight'])

# %%
df1.isna().sum()/len(df1)*100
# Out:
# Unnamed: 0               0.0
# ID                       0.0
# Severity                 0.0
# Start_Time               0.0
# End_Time                 0.0
# Start_Lat                0.0
# Start_Lng                0.0
# Distance(mi)             0.0
# Description              0.0
# Street                   0.0
# Side                     0.0
# City                     0.0
# County                   0.0
# State                    0.0
# Zipcode                  0.0
# Country                  0.0
# Timezone                 0.0
# Airport_Code             0.0
# Weather_Timestamp        0.0
# Temperature(F)           0.0
# Humidity(%)              0.0
# Pressure(in)             0.0
# Visibility(mi)           0.0
# Wind_Direction           0.0
# Wind_Speed(mph)          0.0
# Weather_Condition        0.0
# Amenity                  0.0
# Crossing                 0.0
# Junction                 0.0
# Station                  0.0
# Stop                     0.0
# Traffic_Signal           0.0
# Sunrise_Sunset           0.0
# Civil_Twilight           0.0
# Nautical_Twilight        0.0
# Astronomical_Twilight    0.0
# IDD                      0.0
# dtype: float64

# %%
df1['Weather_Condition'].value_counts()
# Out:
# Fair                  394003
# Cloudy                 77014
# Mostly Cloudy          61942
# Partly Cloudy          51788
# Clear                  42058
#                        ...
# Thunder and Hail           1
# Thunder / Windy            1
# Dust Whirls                1
# Squalls                    1
# Light Freezing Fog         1
# Name: Weather_Condition, Length: 73, dtype: int64

# %%
df1.Side.unique()
# Out:
# array(['R', 'L'], dtype=object)

# %%
df_cat=df1.select_dtypes('object')
df_num=df1.select_dtypes(np.number)
df_cat=df_cat.drop('ID',axis=1)

# %%
df_cat=df1.select_dtypes('object')
col_name=[]
length=[]

for i in df_cat.columns:
    col_name.append(i)
    length.append(len(df_cat[i].unique()))
df_2=pd.DataFrame(zip(col_name,length),columns=['feature','count_of_unique_values'])
df_2
# Out:
#                   feature  count_of_unique_values
# 0                      ID                  741328
# 1              Start_Time                  513129
# 2                End_Time                  630296
# 3             Description                  275439
# 4                  Street                   36875
# 5                    Side                       2
# 6                    City                    1127
# 7                  County                      58
# 8                   State                       1
# 9                 Zipcode                   71221
# 10                Country                       1
# 11               Timezone                       2
# 12           Airport_Code                     139
# 13      Weather_Timestamp                  190616
# 14         Wind_Direction                      23
# 15      Weather_Condition                      73
# 16         Sunrise_Sunset                       2
# 17         Civil_Twilight                       2
# 18      Nautical_Twilight                       2
# 19  Astronomical_Twilight                       2

# %% [markdown]
# num_col=df.select_dtypes('number')
# cat_col=df.select_dtypes('object')
# bool_col=df.select_dtypes('bool')
# float_col=df.select_dtypes('float64')
# int_col=df.select_dtypes('int64')

# %%
df1.drop(['Description','Zipcode','Weather_Timestamp'],axis=1,inplace=True)

# %%
del df1['Airport_Code']

# %%
df_num.columns
# Out:
# Index(['Unnamed: 0', 'Severity', 'Start_Lat', 'Start_Lng', 'Distance(mi)',
#        'Temperature(F)', 'Humidity(%)', 'Pressure(in)', 'Visibility(mi)',
#        'Wind_Speed(mph)', 'IDD'],
#       dtype='object')

# %%
len(df_num.columns)
# Out:
# 11

# %%
df_cat.columns
# Out:
# Index(['ID', 'Start_Time', 'End_Time', 'Description', 'Street', 'Side', 'City',
#        'County', 'State', 'Zipcode', 'Country', 'Timezone', 'Airport_Code',
#        'Weather_Timestamp', 'Wind_Direction', 'Weather_Condition',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df_cat['City'].unique())
# Out:
# 1127

# %%
#cat_col

# %%
#num_col_1=df.select_dtypes('number')

# %% [markdown]
# # Numeric Data

# %%
df_num=df1.select_dtypes(np.number)
col_name=[]
length=[]

for i in df_num.columns:
    col_name.append(i)
    length.append(len(df_num[i].unique()))
df_2=pd.DataFrame(zip(col_name,length),columns=['feature','count_of_unique_values'])
df_2
# Out:
#             feature  count_of_unique_values
# 0        Unnamed: 0                  741328
# 1          Severity                       4
# 2         Start_Lat                  245415
# 3         Start_Lng                  250021
# 4      Distance(mi)                    8070
# 5    Temperature(F)                     458
# 6       Humidity(%)                     100
# 7      Pressure(in)                     805
# 8    Visibility(mi)                      46
# 9   Wind_Speed(mph)                      99
# 10              IDD                  741328

# %%
plt.figure(figsize=(15 ,9))
sns.heatmap(df_num.corr() , annot=True)
# Out:
# <Axes: >

# %%
cities = df1['City'].unique()
len(cities)
# Out:
# 1127

# %%
accidents_by_cities = df1['City'].value_counts()
accidents_by_cities
# Out:
# Los Angeles          63161
# Sacramento           31744
# San Diego            25738
# San Jose             12601
# Riverside            12393
#                      ...
# Green Valley Lake        1
# Cathedral City           1
# Heber                    1
# Forest Falls             1
# Canyon Lake              1
# Name: City, Length: 1127, dtype: int64

# %%
#top 10 cities by number of accident
accidents_by_cities[:10]
# Out:
# Los Angeles       63161
# Sacramento        31744
# San Diego         25738
# San Jose          12601
# Riverside         12393
# Bakersfield       11854
# San Bernardino    10722
# Anaheim            9744
# Ontario            9508
# Oakland            9057
# Name: City, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,5))
accidents_by_cities[:10].plot(kind='bar')
ax.set(title = 'Top 10 cities By Number of Accidents',
       xlabel = 'Cities',
       ylabel = 'Accidents Count')
plt.show()

# %%
accidents_severity = df1.groupby('Severity').count()['ID']
accidents_severity
# Out:
# Severity
# 1      4919
# 2    713159
# 3     15931
# 4      7319
# Name: ID, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8, 6), subplot_kw=dict(aspect="equal"))
label = [1,2,3,4]
plt.pie(accidents_severity, labels=label,
        autopct='%1.1f%%', pctdistance=0.85)
circle = plt.Circle( (0,0), 0.5, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
ax.set_title("Accident by Severity",fontdict={'fontsize': 16})
plt.tight_layout()
plt.show()

# %%
df1['Start_Time'].dtypes
# Out:
# dtype('O')

# %%
df1['End_Time'].dtypes
# Out:
# dtype('O')

# %%
df1 = df1.astype({'Start_Time': 'datetime64[ns]', 'End_Time': 'datetime64[ns]'})
df1['Start_Time'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df1['Start_Time'][2408]
# Out:
# Timestamp('2016-04-29 17:32:55')

# %%
df1['End_Time'][2408]
# Out:
# Timestamp('2016-04-29 23:32:55')

# %%
df1['start_date'] = [d.date() for d in df1['Start_Time']]
df1['start_time'] = [d.time() for d in df1['Start_Time']]

# %%
df1['end_date'] = [d.date() for d in df1['End_Time']]
df1['end_time'] = [d.time() for d in df1['End_Time']]

# %%
df1['end_time']
# Out:
# 880        02:07:32
# 881        03:40:18
# 882        03:36:42
# 883        03:36:42
# 884        09:48:55
#              ...
# 2655878    18:32:01
# 2655879    19:38:23
# 2655880    19:28:49
# 2655881    19:29:42
# 2655882    19:21:31
# Name: end_time, Length: 741328, dtype: object

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.histplot(df1['Start_Time'].dt.hour, bins = 24)

plt.xlabel("Start Time")
plt.ylabel("Number of Occurence")
plt.title('Accidents Count By Time of Day')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.histplot(df1['Start_Time'].dt.hour, bins = 24)

plt.xlabel("End_Time")
plt.ylabel("Number of Occurence")
plt.title('Accidents Count By Time of Day')

plt.show()

# %%
del df1['Start_Time']
del df1['End_Time']

# %%
#df.head()

# %%
# %matplotlib inline
import os

# %% [markdown]
# #  most accidents happened when the weather was 'fair'. Perhaps weather (bad weather) was not a big contributing factor to accidents.

# %%
#df_num.head()

# %%
# shape of original data -> 2845342 rows

# %%
df1.shape  # shape of data after removing null values
# Out:
# (741328, 35)

# %%
df_num.shape
# Out:
# (741328, 11)

# %%
# Accidents by order of severity (1 being lowest, and 4 being highest)

df1.groupby('Severity').count()['IDD']
# Out:
# Severity
# 1      4919
# 2    713159
# 3     15931
# 4      7319
# Name: IDD, dtype: int64

# %%
# scatter plot

# %%
df_num.plot(kind='scatter', y='Start_Lat', x='Severity')
# Out:
# <Axes: xlabel='Severity', ylabel='Start_Lat'>

# %%
sns.jointplot(x=df_num.Start_Lat.values , y=df_num.Start_Lng.values,height=10)
plt.ylabel('Start lattitude', fontsize=12)
plt.xlabel('Start lattitude', fontsize=12)
plt.show()
